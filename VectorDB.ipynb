# %% [markdown]
# ## Vector DB & Vector Store

# %% [markdown]
# ##### Vector Database: A full database system optimized for vector operations, with features like indexing, persistence, and querying (e.g., Pinecone, Weaviate, Milvus).
#
# ##### Vector Store: Often refers to the storage component within a framework (e.g., LangChain's VectorStore) that handles vector persistence and retrieval, sometimes as part of a larger pipeline

# %%
from langchain_ollama import OllamaEmbeddings
from langchain_chroma import Chroma

# %%
from langchain_core.documents import Document

# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
vector_store = Chroma(
    embedding_function=OllamaEmbeddings(model="qwen3-embedding:8b"),
    persist_directory='chroma_db_new',
    collection_name='sample'
)

# %%
# add documents
vector_store.add_documents(docs)
# Out:
# ['87ed2a9f-44d6-4570-aa8e-2a156f1bd75f',
#  '3416fb3d-4ced-41af-8514-264330d5f8a8',
#  '37633ae5-5559-45b4-8db8-78cd77909c72',
#  '397765a8-3be9-4a03-ae71-f17f6854d702',
#  '7d49390c-0f00-4635-aadb-d791875bde14']

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['87ed2a9f-44d6-4570-aa8e-2a156f1bd75f',
#   '3416fb3d-4ced-41af-8514-264330d5f8a8',
#   '37633ae5-5559-45b4-8db8-78cd77909c72',
#   '397765a8-3be9-4a03-ae71-f17f6854d702',
#   '7d49390c-0f00-4635-aadb-d791875bde14'],
#  'embeddings': array([[ 0.01857933,  0.00144977,  0.00788271, ...,  0.00342908,
#           0.01431386, -0.01368329],
#         [ 0.0015947 ,  0.00032829, -0.01313653, ...,  0.02315043,
#           0.00037214, -0.00246912],
#         [ 0.00449242,  0.00272021, -0.01055914, ...,  0.02115665,
#          -0.00397489, -0.01703812],
#         [ 0.03536054,  0.02713986,  0.02652941, ...,  0.00422566,
#           0.01000787, -0.00898326],
#         [ 0.02533408,  0.00643438,  0.00760356, ...,  0.01981907,
#           0.01369712, -0.01236483]], shape=(5, 4096)),
# ...

# %%
# search documents
vector_store.similarity_search(
    query='Who among these are a bowler?',
    k=2
)
# Out:
# [Document(id='397765a8-3be9-4a03-ae71-f17f6854d702', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(id='7d49390c-0f00-4635-aadb-d791875bde14', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.')]

# %%
# search with similarity score
vector_store.similarity_search_with_score(
    query='Who among these are a bowler?',
    k=2
)
# Out:
# [(Document(id='397765a8-3be9-4a03-ae71-f17f6854d702', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.8264961242675781),
#  (Document(id='7d49390c-0f00-4635-aadb-d791875bde14', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.9584566950798035)]

# %%
# meta-data filtering
vector_store.similarity_search_with_score(
    query="",
    filter={"team": "Chennai Super Kings"}
)
# Out:
# [(Document(id='7d49390c-0f00-4635-aadb-d791875bde14', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   1.5901155471801758),
#  (Document(id='37633ae5-5559-45b4-8db8-78cd77909c72', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   1.6567175388336182)]

# %%
# update documents
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='3416fb3d-4ced-41af-8514-264330d5f8a8', document=updated_doc1)

# %%
# view documents
vector_store.get(ids=['3416fb3d-4ced-41af-8514-264330d5f8a8'], include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['3416fb3d-4ced-41af-8514-264330d5f8a8'],
#  'embeddings': array([[ 0.00606461,  0.00463506,  0.00182395, ..., -0.00138127,
#           0.01819573, -0.00152221]], shape=(1, 4096)),
#  'documents': ["Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket."],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'}]}
